# %% [markdown]
# <a href="https://colab.research.google.com/github/ColbyLe/CS499A3_and_A4/blob/master/CS499A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **CS 4990 Assignment 3: Hair/Face Segmentation**

# %%
# retrieve data from git repo
# !git clone https://github.com/ColbyLe/CS499A3_Data.git
# Out:
# Cloning into 'CS499A3_Data'...
# remote: Enumerating objects: 3169, done.
# remote: Counting objects: 100% (3169/3169), done.
# remote: Compressing objects: 100% (3104/3104), done.
# remote: Total 17416 (delta 67), reused 3166 (delta 65), pack-reused 14247
# Receiving objects: 100% (17416/17416), 197.47 MiB | 10.42 MiB/s, done.
# Resolving deltas: 100% (2477/2477), done.
# Checking out files: 100% (10065/10065), done.

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

from keras import layers
from keras.models import Model, load_model, Sequential
from keras.applications import imagenet_utils
from keras.layers import Input, Conv2D, Conv2DTranspose, concatenate, MaxPooling2D, Flatten, Dropout, BatchNormalization, Lambda, GaussianNoise
from keras.layers import Dense, Reshape
from keras.losses import binary_crossentropy
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K

import tensorflow as tf

from sklearn.model_selection import train_test_split
from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images, imsave
from skimage.transform import resize
from skimage.morphology import label

import matplotlib.pyplot as plt

import re
import random

# %% [markdown]
# ## **I. Data Processing**

# %%
# set initial parameters
img_height = 256
img_width = 256
img_channels = 3

# set paths to data folders
train_X_path = 'CS499A3_Data/training_images/'
valid_X_path = 'CS499A3_Data/validation_images/'

train_Y_path = 'CS499A3_Data/training_masks/'
valid_Y_path = 'CS499A3_Data/validation_masks/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
num_classes = 1

# 2 classes for hair/skin segmentation
# num_classes = 2
# use categorical crossentropy w/ dice loss as loss function

# %%
# get training and testing IDs
# sort lists into same order
train_X_ids = next(os.walk(train_X_path))[2]
train_X_ids.sort()
valid_X_ids = next(os.walk(valid_X_path))[2]
valid_X_ids.sort()

train_Y_ids = next(os.walk(train_Y_path))[2]
train_Y_ids.sort()
valid_Y_ids = next(os.walk(valid_Y_path))[2]
valid_Y_ids.sort()

# %%
# get data and resize
# instantiate empty arrays for training images and masks
X_train = np.zeros((len(train_X_ids), img_height, img_width, img_channels), dtype=np.uint8)
Y_train = np.zeros((len(train_Y_ids), img_height, img_width, 1), dtype=np.bool)

# get and resize training images
print("Getting training images\n")
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_X_ids), total=len(train_X_ids)):
  X_path = train_X_path + id_
  img = imread(X_path)[:,:,:img_channels]
  img = resize(img, (img_height, img_width), mode='constant', preserve_range=True)
  X_train[n] = img

sys.stdout.flush()

# get and resize training masks
print("\nGetting training masks")
sys.stdout.flush()
mask = np.zeros((img_height, img_width,1), dtype=np.bool)
for n, id_ in tqdm(enumerate(train_Y_ids), total=len(train_Y_ids)):
  Y_path = train_Y_path + id_
  mask_ = imread(Y_path, as_gray=True)
  mask_ = np.expand_dims(resize(mask_, (img_height, img_width), mode='constant', preserve_range=True), axis=-1)
  # perform feature scaling
  mask_ = np.round(mask_/255)
  mask_ = resize(mask_, (img_height, img_width), mode='constant', preserve_range=True)
  mask = np.maximum(mask, mask_)
  Y_train[n] = mask_

# instantiate empty arrays for validation images and masks
X_valid = np.zeros((len(valid_X_ids), img_height, img_width, img_channels), dtype=np.uint8)
Y_valid = np.zeros((len(valid_Y_ids), img_height, img_width, 1), dtype=np.bool)

# get and resize validation images
print("\nGetting validation images")
sys.stdout.flush()
for n, id_ in tqdm(enumerate(valid_X_ids), total=len(valid_X_ids)):
  X_path = valid_X_path + id_
  img = imread(X_path)[:,:,:img_channels]
  img = resize(img, (img_height, img_width), mode='constant', preserve_range=True)
  X_valid[n] = img

# get and resize validation masks
print("\nGetting validation masks")
sys.stdout.flush()
mask = np.zeros((img_height, img_width,1), dtype=np.bool)
for n, id_ in tqdm(enumerate(valid_Y_ids), total=len(valid_Y_ids)):
  Y_path = valid_Y_path + id_
  mask_ = imread(Y_path)
  mask_ = np.expand_dims(resize(mask_, (img_height, img_width), mode='constant', preserve_range=True),axis=-1)
  # perform feature scaling
  mask_ = np.round(mask_/255)
  mask_ = resize(mask_, (img_height, img_width), mode='constant', preserve_range=True)
  mask = np.maximum(mask, mask_)
  Y_valid[n] = mask_
# Out:
# Getting training images
# 100%|██████████| 1500/1500 [00:15<00:00, 94.41it/s]
# Getting training masks
# 100%|██████████| 1500/1500 [00:11<00:00, 126.38it/s]
# Getting validation images
# 100%|██████████| 500/500 [00:05<00:00, 94.33it/s]
# Getting validation masks
# 100%|██████████| 500/500 [00:03<00:00, 128.58it/s]

# %%
# Check if training data looks all right
ix = random.randint(0, len(X_train))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %% [markdown]
# # **II. Model Definition**

# %% [markdown]
# **CFCN-seg**

# %%
# support functions for CFCN-seg
# dice coefficient metric
def dice_coeff(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

# loss function based on dice coefficient
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# loss function combining binary crossentropy and dice loss
def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

# %%
# define CFCN-seg
# define input shape
inputs = Input((img_height, img_width, img_channels))
# perform feature scaling on inputs
s = Lambda(lambda x: x/255)(inputs)
# additional Gaussian Noise layer to reduce overfitting
s = GaussianNoise(0.01)(s)

# convolutional encoder blocks 
# each convolutional block is similar to the ones used in Assignment 2, but with additional batch normalization and dropout layers after each pooling layer to reduce overfittingr
c11 = Conv2D(64, kernel_size=(3,3), strides=1, padding='same', activation='relu')(s)
p11 = MaxPooling2D(2,2)(c11)
l11 = BatchNormalization()(p11)
l11 = Dropout(0.5)(l11)
c12 = Conv2D(64, kernel_size=(3,3), strides=1, padding='same', activation='relu')(l11)
p12 = MaxPooling2D(2,2)(c12)
l1 = BatchNormalization()(p12)
l1 = Dropout(0.5)(l1)
'''
l1 = Flatten()(l1)
l1 = Dense(64, activation='softmax')(l1)
l1 = Reshape((128,129,64))(l1)
'''

c21 = Conv2D(128, kernel_size=(3,3), strides=1, padding='same', activation='relu')(l1)
p21 = MaxPooling2D(2,2)(c21)
l21 = BatchNormalization()(p21)
l21 = Dropout(0.5)(l21)
c22 = Conv2D(128, kernel_size=(3,3), strides=1, padding='same', activation='relu')(l21)
p22 = MaxPooling2D(2,2)(c22)
l2 = BatchNormalization()(p22)
l2 = Dropout(0.5)(l2)

# additional convolutional blocks in encoder to improve model accuracy
cn1 = Conv2D(256, kernel_size=(3,3), strides=1, padding='same', activation='relu')(l2)
pn1 = MaxPooling2D(2,2)(cn1)
ln1 = BatchNormalization()(pn1)
ln1 = Dropout(0.5)(ln1)
co1 = Conv2D(256, kernel_size=(3,3), strides=1, padding='same', activation='relu')(ln1)
po1 = MaxPooling2D(2,2)(co1)
lo1 = BatchNormalization()(po1)
lo1 = Dropout(0.5)(lo1)

cp1 = Conv2D(512, kernel_size=(3,3), strides=1, padding='same', activation='relu')(lo1)
pp1 = MaxPooling2D(2,2)(cp1)
lp1 = BatchNormalization()(pp1)
lp1 = Dropout(0.5)(lp1)
cq1 = Conv2D(512, kernel_size=(3,3), strides=1, padding='same', activation='relu')(lp1)
pq1 = MaxPooling2D(2,2)(cq1)
lq1 = BatchNormalization()(pq1)
lq1 = Dropout(0.5)(lq1)

'''
c3 = Conv2D(1024, kernel_size=(3,3), strides=1, padding='same', activation='relu')(lq1)
l3 = BatchNormalization()(c3)
l3 = Dropout(0.5)(l3)
c3 = Conv2D(1024, kernel_size=(3,3), strides=1, padding='same', activation='relu')(l3)
c3 = BatchNormalization()(c3)
c3 = Dropout(0.5)(c3)
'''


# testing dense layer in place of interstitial block
c3 = Flatten()(lq1)
c3 = Dense(1024, activation='softmax')(c3)
c3 = Reshape((1,1,1024))(c3)


# decoder blocks
# based on decoder blocks used in U-Net

# additional decoder blocks to match encoder blocks
up4 = Conv2DTranspose(512, (2,2), strides=(2,2), padding='same')(c3)
up4 = concatenate([cq1, up4])
cp4 = Conv2D(512, kernel_size=(3,3), strides=1, padding='same', activation='relu')(up4)
lp4 = BatchNormalization()(cp4)
lp4 = Dropout(0.5)(lp4)
cp4 = Conv2D(512, kernel_size=(3,3), strides=1, padding='same', activation='relu')(lp4)

uq4 = Conv2DTranspose(512, (2,2), strides=(2,2), padding='same')(cp4)
uq4 = concatenate([cp1, uq4])
cq4 = Conv2D(512, kernel_size=(3,3), strides=1, padding='same', activation='relu')(uq4)
lq4 = BatchNormalization()(cq4)
lq4 = Dropout(0.5)(lq4)
cq4 = Conv2D(512, kernel_size=(3,3), strides=1, padding='same', activation='relu')(lq4)

un4 = Conv2DTranspose(256, (2,2), strides=(2,2), padding='same')(cq4)
un4 = concatenate([co1, un4])
cn4 = Conv2D(256, kernel_size=(3,3), strides=1, padding='same', activation='relu')(un4)
ln4 = BatchNormalization()(cn4)
ln4 = Dropout(0.5)(ln4)
cn4 = Conv2D(256, kernel_size=(3,3), strides=1, padding='same', activation='relu')(ln4)

uo4 = Conv2DTranspose(256, (2,2), strides=(2,2), padding='same')(cn4)
uo4 = concatenate([cn1, uo4])
co4 = Conv2D(256, kernel_size=(3,3), strides=1, padding='same', activation='relu')(uo4)
lo4 = BatchNormalization()(co4)
lo4 = Dropout(0.5)(lo4)
co4 = Conv2D(256, kernel_size=(3,3), strides=1, padding='same', activation='relu')(lo4)

u4 = Conv2DTranspose(128, (2,2), strides=(2,2), padding='same')(co4)
u4 = concatenate([c22, u4])
c4 = Conv2D(128, kernel_size=(3,3), strides=1, padding='same', activation='relu')(u4)
l4 = BatchNormalization()(c4)
l4 = Dropout(0.5)(l4)
c4 = Conv2D(128, kernel_size=(3,3), strides=1, padding='same', activation='relu')(l4)

u5 = Conv2DTranspose(128, (2,2), strides=(2,2), padding='same')(c4)
u5 = concatenate([c21, u5])
c5 = Conv2D(128, kernel_size=(3,3), strides=1, padding='same', activation='relu')(u5)
l5 = BatchNormalization()(c5)
l5 = Dropout(0.5)(l5)
c5 = Conv2D(128, kernel_size=(3,3), strides=1, padding='same', activation='relu')(l5)

u6 = Conv2DTranspose(64, (2,2), strides=(2,2), padding='same')(c5)
u6 = concatenate([c12, u6])
c6 = Conv2D(64, kernel_size=(3,3), strides=1, padding='same', activation='relu')(u6)
l6 = BatchNormalization()(c6)
l6 = Dropout(0.5)(l6)
c6 = Conv2D(64, kernel_size=(3,3), strides=1, padding='same', activation='relu')(l6)

u7 = Conv2DTranspose(64, (2,2), strides=(2,2), padding='same')(c6)
u7 = concatenate([c11, u7])
c7 = Conv2D(64, kernel_size=(3,3), strides=1, padding='same', activation='relu')(u7)
l7 = BatchNormalization()(c7)
l7 = Dropout(0.5)(l7)
c7 = Conv2D(64, kernel_size=(3,3), strides=1, padding='same', activation='relu')(l7)

# output layer
# same as U-Net
outputs = Conv2D(1, (1, 1), activation='sigmoid') (c7)

model = Model(inputs=[inputs], outputs=[outputs])
model.name = 'CFCN-seg'
model.summary()

# compile model with custom loss function and metric
# using bce dice loss instead of binary crossentropy improves model performance
model.compile(optimizer='adam', loss=bce_dice_loss, metrics=[dice_coeff])
# Out:
# Model: "CFCN-seg"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 256, 256, 3)  0           input_8[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_8 (GaussianNoise (None, 256, 256, 3)  0           lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 256, 256, 64) 1792        gaussian_noise_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 128, 128, 64) 0           conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 128, 128, 64) 256         max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 128, 128, 64) 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 128, 128, 64) 36928       dropout_49[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 64, 64, 64)   0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 64, 64, 64)   256         max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 64, 64, 64)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 64, 64, 128)  73856       dropout_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 32, 32, 128)  0           conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 32, 32, 128)  512         max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 32, 32, 128)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 128)  147584      dropout_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 16, 16, 128)  0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 16, 16, 128)  512         max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 16, 16, 128)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 16, 16, 256)  295168      dropout_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 8, 8, 256)    0           conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 256)    1024        max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 8, 8, 256)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 8, 8, 256)    590080      dropout_53[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 4, 4, 256)    0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 4, 4, 256)    1024        max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 4, 4, 256)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 4, 4, 512)    1180160     dropout_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 2, 2, 512)    0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 2, 2, 512)    2048        max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 2, 2, 512)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 2, 2, 512)    2359808     dropout_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 1, 1, 512)    0           conv2d_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 1, 1, 512)    2048        max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 1, 1, 512)    0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 512)          0           dropout_56[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1024)         525312      flatten_8[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 1024)   0           dense_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 2, 2, 512)    2097664     reshape_6[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 2, 2, 1024)   0           conv2d_75[0][0]
#                                                                  conv2d_transpose_17[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 2, 2, 512)    4719104     concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 2, 2, 512)    2048        conv2d_76[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 2, 2, 512)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 2, 2, 512)    2359808     dropout_57[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 4, 4, 512)    1049088     conv2d_77[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 4, 4, 1024)   0           conv2d_74[0][0]
#                                                                  conv2d_transpose_18[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 4, 4, 512)    4719104     concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 4, 4, 512)    2048        conv2d_78[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 4, 4, 512)    0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 4, 4, 512)    2359808     dropout_58[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 8, 8, 256)    524544      conv2d_79[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 8, 8, 512)    0           conv2d_73[0][0]
#                                                                  conv2d_transpose_19[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 256)    1179904     concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 8, 8, 256)    1024        conv2d_80[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 8, 8, 256)    0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 256)    590080      dropout_59[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 16, 16, 256)  262400      conv2d_81[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 16, 16, 512)  0           conv2d_72[0][0]
#                                                                  conv2d_transpose_20[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 16, 16, 256)  1024        conv2d_82[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 16, 16, 256)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 16, 16, 256)  590080      dropout_60[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 32, 32, 128)  131200      conv2d_83[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 32, 32, 256)  0           conv2d_71[0][0]
#                                                                  conv2d_transpose_21[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 32, 128)  512         conv2d_84[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 32, 32, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 32, 32, 128)  147584      dropout_61[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 64, 64, 128)  65664       conv2d_85[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 64, 64, 256)  0           conv2d_70[0][0]
#                                                                  conv2d_transpose_22[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 64, 64, 128)  512         conv2d_86[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 64, 64, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 64, 64, 128)  147584      dropout_62[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 128, 128, 64) 32832       conv2d_87[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 128, 128, 128 0           conv2d_69[0][0]
#                                                                  conv2d_transpose_23[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 128, 128, 64) 256         conv2d_88[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 128, 128, 64) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 128, 128, 64) 36928       dropout_63[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 256, 256, 64) 16448       conv2d_89[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 256, 256, 128 0           conv2d_68[0][0]
#                                                                  conv2d_transpose_24[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 256, 256, 64) 256         conv2d_90[0][0]
# __________________________________________________________________________________________________
# dropout_64 (Dropout)            (None, 256, 256, 64) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 256, 256, 64) 36928       dropout_64[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 256, 256, 1)  65          conv2d_91[0][0]
# ==================================================================================================
# Total params: 28,210,433
# Trainable params: 28,202,753
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %% [markdown]
# # **III. Training**

# %%
earlystopper = EarlyStopping(patience=100, verbose=1, monitor='val_loss', mode='max')
cp = ModelCheckpoint('A3-weights.h5', verbose=1, monitor='val_dice_coeff', mode='max', save_best_only=True)
batch = 5

# %%
print(model.name)
res = model.fit(X_train, Y_train, batch_size=batch, epochs=50, callbacks=[cp], validation_data=(X_valid, Y_valid))
#res = model.fit(X_train, Y_train, batch_size=batch, epochs=500, callbacks=[cp], validation_data=(X_valid, Y_valid))
# Out:
# CFCN-seg
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 1500 samples, validate on 500 samples
# Epoch 1/50
# 1500/1500 [==============================] - 74s 50ms/step - loss: 0.8371 - dice_coeff: 0.4562 - val_loss: 0.7484 - val_dice_coeff: 0.5776
#
# Epoch 00001: val_dice_coeff improved from -inf to 0.57755, saving model to A3-weights.h5
# Epoch 2/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.7006 - dice_coeff: 0.5421 - val_loss: 0.8020 - val_dice_coeff: 0.5816
#
# Epoch 00002: val_dice_coeff improved from 0.57755 to 0.58158, saving model to A3-weights.h5
# Epoch 3/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.6563 - dice_coeff: 0.5722 - val_loss: 0.6460 - val_dice_coeff: 0.6305
#
# Epoch 00003: val_dice_coeff improved from 0.58158 to 0.63047, saving model to A3-weights.h5
# Epoch 4/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.6107 - dice_coeff: 0.6044 - val_loss: 0.5775 - val_dice_coeff: 0.6292
#
# Epoch 00004: val_dice_coeff did not improve from 0.63047
# Epoch 5/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.5769 - dice_coeff: 0.6287 - val_loss: 0.5839 - val_dice_coeff: 0.6642
#
# Epoch 00005: val_dice_coeff improved from 0.63047 to 0.66422, saving model to A3-weights.h5
# Epoch 6/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.5397 - dice_coeff: 0.6506 - val_loss: 0.5538 - val_dice_coeff: 0.6490
#
# Epoch 00006: val_dice_coeff did not improve from 0.66422
# Epoch 7/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.4940 - dice_coeff: 0.6833 - val_loss: 0.4803 - val_dice_coeff: 0.7037
#
# Epoch 00007: val_dice_coeff improved from 0.66422 to 0.70366, saving model to A3-weights.h5
# Epoch 8/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.4677 - dice_coeff: 0.7005 - val_loss: 0.4488 - val_dice_coeff: 0.6940
#
# Epoch 00008: val_dice_coeff did not improve from 0.70366
# Epoch 9/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.4356 - dice_coeff: 0.7218 - val_loss: 0.4127 - val_dice_coeff: 0.7461
#
# Epoch 00009: val_dice_coeff improved from 0.70366 to 0.74606, saving model to A3-weights.h5
# Epoch 10/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.4108 - dice_coeff: 0.7380 - val_loss: 0.3453 - val_dice_coeff: 0.7747
#
# Epoch 00010: val_dice_coeff improved from 0.74606 to 0.77472, saving model to A3-weights.h5
# Epoch 11/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.3936 - dice_coeff: 0.7483 - val_loss: 0.3494 - val_dice_coeff: 0.7930
#
# Epoch 00011: val_dice_coeff improved from 0.77472 to 0.79296, saving model to A3-weights.h5
# Epoch 12/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.3734 - dice_coeff: 0.7612 - val_loss: 0.3562 - val_dice_coeff: 0.7747
#
# Epoch 00012: val_dice_coeff did not improve from 0.79296
# Epoch 13/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.3551 - dice_coeff: 0.7728 - val_loss: 0.3258 - val_dice_coeff: 0.8020
#
# Epoch 00013: val_dice_coeff improved from 0.79296 to 0.80200, saving model to A3-weights.h5
# Epoch 14/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.3416 - dice_coeff: 0.7829 - val_loss: 0.3275 - val_dice_coeff: 0.8008
#
# Epoch 00014: val_dice_coeff did not improve from 0.80200
# Epoch 15/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.3216 - dice_coeff: 0.7950 - val_loss: 0.3233 - val_dice_coeff: 0.7958
#
# Epoch 00015: val_dice_coeff did not improve from 0.80200
# Epoch 16/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.3161 - dice_coeff: 0.7978 - val_loss: 0.3357 - val_dice_coeff: 0.7909
#
# Epoch 00016: val_dice_coeff did not improve from 0.80200
# Epoch 17/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2989 - dice_coeff: 0.8090 - val_loss: 0.3020 - val_dice_coeff: 0.8165
#
# Epoch 00017: val_dice_coeff improved from 0.80200 to 0.81654, saving model to A3-weights.h5
# Epoch 18/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2907 - dice_coeff: 0.8140 - val_loss: 0.3125 - val_dice_coeff: 0.8137
#
# Epoch 00018: val_dice_coeff did not improve from 0.81654
# Epoch 19/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2914 - dice_coeff: 0.8131 - val_loss: 0.3002 - val_dice_coeff: 0.8199
#
# Epoch 00019: val_dice_coeff improved from 0.81654 to 0.81990, saving model to A3-weights.h5
# Epoch 20/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2685 - dice_coeff: 0.8288 - val_loss: 0.2867 - val_dice_coeff: 0.8197
#
# Epoch 00020: val_dice_coeff did not improve from 0.81990
# Epoch 21/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2675 - dice_coeff: 0.8299 - val_loss: 0.2809 - val_dice_coeff: 0.8348
#
# Epoch 00021: val_dice_coeff improved from 0.81990 to 0.83475, saving model to A3-weights.h5
# Epoch 22/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2546 - dice_coeff: 0.8379 - val_loss: 0.2926 - val_dice_coeff: 0.8201
#
# Epoch 00022: val_dice_coeff did not improve from 0.83475
# Epoch 23/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2604 - dice_coeff: 0.8336 - val_loss: 0.3297 - val_dice_coeff: 0.7990
#
# Epoch 00023: val_dice_coeff did not improve from 0.83475
# Epoch 24/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2648 - dice_coeff: 0.8313 - val_loss: 0.3168 - val_dice_coeff: 0.8104
#
# Epoch 00024: val_dice_coeff did not improve from 0.83475
# Epoch 25/50
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.2443 - dice_coeff: 0.8443 - val_loss: 0.2730 - val_dice_coeff: 0.8328
#
# Epoch 00025: val_dice_coeff did not improve from 0.83475
# Epoch 26/50
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.2405 - dice_coeff: 0.8466 - val_loss: 0.3417 - val_dice_coeff: 0.7941
#
# Epoch 00026: val_dice_coeff did not improve from 0.83475
# Epoch 27/50
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.2362 - dice_coeff: 0.8497 - val_loss: 0.3052 - val_dice_coeff: 0.8126
#
# Epoch 00027: val_dice_coeff did not improve from 0.83475
# Epoch 28/50
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.2358 - dice_coeff: 0.8501 - val_loss: 0.2700 - val_dice_coeff: 0.8367
#
# Epoch 00028: val_dice_coeff improved from 0.83475 to 0.83675, saving model to A3-weights.h5
# Epoch 29/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2263 - dice_coeff: 0.8557 - val_loss: 0.2678 - val_dice_coeff: 0.8339
#
# Epoch 00029: val_dice_coeff did not improve from 0.83675
# Epoch 30/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2272 - dice_coeff: 0.8550 - val_loss: 0.2891 - val_dice_coeff: 0.8282
#
# Epoch 00030: val_dice_coeff did not improve from 0.83675
# Epoch 31/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2277 - dice_coeff: 0.8546 - val_loss: 0.2772 - val_dice_coeff: 0.8295
#
# Epoch 00031: val_dice_coeff did not improve from 0.83675
# Epoch 32/50
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.2179 - dice_coeff: 0.8609 - val_loss: 0.2523 - val_dice_coeff: 0.8419
#
# Epoch 00032: val_dice_coeff improved from 0.83675 to 0.84187, saving model to A3-weights.h5
# Epoch 33/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2136 - dice_coeff: 0.8639 - val_loss: 0.2700 - val_dice_coeff: 0.8374
#
# Epoch 00033: val_dice_coeff did not improve from 0.84187
# Epoch 34/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2141 - dice_coeff: 0.8638 - val_loss: 0.2689 - val_dice_coeff: 0.8420
#
# Epoch 00034: val_dice_coeff improved from 0.84187 to 0.84198, saving model to A3-weights.h5
# Epoch 35/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2212 - dice_coeff: 0.8587 - val_loss: 0.2776 - val_dice_coeff: 0.8360
#
# Epoch 00035: val_dice_coeff did not improve from 0.84198
# Epoch 36/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2143 - dice_coeff: 0.8630 - val_loss: 0.3067 - val_dice_coeff: 0.8263
#
# Epoch 00036: val_dice_coeff did not improve from 0.84198
# Epoch 37/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.2114 - dice_coeff: 0.8641 - val_loss: 0.2900 - val_dice_coeff: 0.8331
#
# Epoch 00037: val_dice_coeff did not improve from 0.84198
# Epoch 38/50
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.2028 - dice_coeff: 0.8698 - val_loss: 0.2597 - val_dice_coeff: 0.8438
#
# Epoch 00038: val_dice_coeff improved from 0.84198 to 0.84383, saving model to A3-weights.h5
# Epoch 39/50
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.1919 - dice_coeff: 0.8767 - val_loss: 0.2512 - val_dice_coeff: 0.8538
#
# Epoch 00039: val_dice_coeff improved from 0.84383 to 0.85377, saving model to A3-weights.h5
# Epoch 40/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.1984 - dice_coeff: 0.8732 - val_loss: 0.2939 - val_dice_coeff: 0.8238
#
# Epoch 00040: val_dice_coeff did not improve from 0.85377
# Epoch 41/50
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.2014 - dice_coeff: 0.8705 - val_loss: 0.2594 - val_dice_coeff: 0.8515
#
# Epoch 00041: val_dice_coeff did not improve from 0.85377
# Epoch 42/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.1954 - dice_coeff: 0.8745 - val_loss: 0.2504 - val_dice_coeff: 0.8537
#
# Epoch 00042: val_dice_coeff did not improve from 0.85377
# Epoch 43/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.1853 - dice_coeff: 0.8814 - val_loss: 0.2815 - val_dice_coeff: 0.8417
#
# Epoch 00043: val_dice_coeff did not improve from 0.85377
# Epoch 44/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.1878 - dice_coeff: 0.8801 - val_loss: 0.2526 - val_dice_coeff: 0.8478
#
# Epoch 00044: val_dice_coeff did not improve from 0.85377
# Epoch 45/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.1858 - dice_coeff: 0.8810 - val_loss: 0.2599 - val_dice_coeff: 0.8496
#
# Epoch 00045: val_dice_coeff did not improve from 0.85377
# Epoch 46/50
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.1867 - dice_coeff: 0.8804 - val_loss: 0.2533 - val_dice_coeff: 0.8529
#
# Epoch 00046: val_dice_coeff did not improve from 0.85377
# Epoch 47/50
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.1791 - dice_coeff: 0.8854 - val_loss: 0.2460 - val_dice_coeff: 0.8523
#
# Epoch 00047: val_dice_coeff did not improve from 0.85377
# Epoch 48/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.1782 - dice_coeff: 0.8859 - val_loss: 0.2719 - val_dice_coeff: 0.8497
#
# Epoch 00048: val_dice_coeff did not improve from 0.85377
# Epoch 49/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.1817 - dice_coeff: 0.8839 - val_loss: 0.2530 - val_dice_coeff: 0.8496
#
# Epoch 00049: val_dice_coeff did not improve from 0.85377
# Epoch 50/50
# 1500/1500 [==============================] - 61s 41ms/step - loss: 0.1764 - dice_coeff: 0.8867 - val_loss: 0.2523 - val_dice_coeff: 0.8523
#
# Epoch 00050: val_dice_coeff did not improve from 0.85377

# %% [markdown]
# # **IV. Prediction Processing**

# %%
# optional cell to load trained model
model = load_model('A3-weights.h5', custom_objects={"dice_coeff": dice_coeff, "bce_dice_loss":bce_dice_loss})

# %%
# generate predictions on validation set
preds_val = model.predict(X_valid, verbose=1)
# Out:
# 500/500 [==============================] - 13s 26ms/step

# %%
# perform visual comparison of predicted mask and actual mask on validation set
ix = random.randint(0, len(preds_val))
imshow(X_valid[ix])
plt.show()
imshow(np.squeeze(Y_valid[ix]))
plt.show()
imshow(np.squeeze(np.round(preds_val[ix])))
plt.show()

# %%
# prepare testing images
test_path = 'CS499A3_Data/testing_images/'
# generate list of test ids
test_ids = next(os.walk(test_path))[2]

# create empty array to store test masks
X_test = np.zeros((len(test_ids), img_height, img_width, img_channels), dtype=np.uint8)

# get and resize training images
print("Getting testing images\n")
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
  X_path = test_path + id_
  img = imread(X_path)[:,:,:img_channels]
  img = resize(img, (img_height, img_width), mode='constant', preserve_range=True)
  X_test[n] = img
# Out:
# Getting testing images
# 100%|██████████| 927/927 [00:10<00:00, 88.58it/s]

# %%
# generate test predictions
test_preds = model.predict(X_test, verbose=1)
# Out:
# 927/927 [==============================] - 13s 14ms/step

# %%
# perform visual comparison of predicted mask on testing set
ix = random.randint(0, len(test_preds))
print(test_ids[ix])
imshow(X_test[ix])
plt.show()
imshow(np.squeeze(np.round(test_preds[ix])))
plt.show()
# Out:
# test_img_11.jpg

# %%
# save masks
for x, y, z in zip(test_preds, X_test, test_ids):
  # save masks and images in temporary files, then load again to resize
  imsave("test_y.jpg", np.squeeze(np.round(x)*255).astype('uint8'))
  img_y = imread("test_y.jpg")
  img_y = resize(img_y, (250, 250), mode='constant', preserve_range=True)

  imsave("test_x.jpg", np.squeeze(np.round(y)*255).astype('uint8'))
  img_x = imread("test_x.jpg")
  img_x = resize(img_x, (250, 250), mode='constant', preserve_range=True)

  # save final mask files in new directory
  mask_id = re.split('_|\.', z)[2]
  mask_name = 'CS499A3_Data/testing_masks/test_mask_' + mask_id +'.jpg'
  imsave(mask_name, img_y.astype('uint8'))

# %%
# generate sorted list of test mask ids
test_y_ids = []
for i in range(len(test_preds)):
  curr_id = 'test_mask_' + str(i+1) + '.jpg'
  test_y_ids.append(curr_id)

# %% [markdown]
# # **V. Export**

# %%
# encoding function
# based on the implementation: https://www.kaggle.com/rakhlin/fast-run-length-encoding-python/code
def rle_encoding(x):
    '''
    x: numpy array of shape (height, width), 1 - mask, 0 - background
    Returns run length as list
    '''
    dots = np.where(x.T.flatten()==1)[0] # .T sets Fortran order down-then-right
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b+1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

# %%
input_path = 'CS499A3_Data/testing_masks'
masks = test_y_ids

# encode all masks
encodings = []
for file in masks:
    mask = imread(os.path.join(input_path, file))
    #img_size =10
    #mask = resize(mask, (img_size, img_size), mode='constant', preserve_range=True)
    mask = np.array(mask, dtype=np.uint8)
    mask = np.round(mask/255)
    encodings.append(rle_encoding(mask))


# (** update) the path where to save the submission csv file
sub = pd.DataFrame()
sub['ImageId'] = pd.Series(masks).apply(lambda x: os.path.splitext(x)[0])
sub['EncodedPixels'] = pd.Series(encodings).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv(os.path.join('/content/', 'test_seg.csv'), index=False)
